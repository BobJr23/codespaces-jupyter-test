# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import cv2
image = cv2.imread(r"/workspaces/codespaces-jupyter-test/data/image.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
thresh = cv2.inRange(image, (0, 0, 180), (60, 255, 255))
thresh = cv2.cvtColor(thresh, cv2.COLOR_BGR2RGB)
plt.imshow(thresh)
plt.show()

# %%
import numpy as np
points = np.where(thresh == 255)
mini = (points[1].min()-2, points[0].max()-2)
maxi = (points[1].max()+2, points[0].min()+2)
cv2.line(image, mini, maxi, (255, 0, 0), 3)
plt.imshow(image)
plt.show()

# %%
template = cv2.imread(r"/workspaces/codespaces-jupyter-test/data/test.png", cv2.IMREAD_GRAYSCALE)
image1 = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

res = cv2.matchTemplate(image1, template, cv2.TM_CCOEFF_NORMED)
print(cv2.minMaxLoc(res))
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

top_left = max_loc
bottom_right = (top_left[0] + 17, top_left[1] + 20)
cv2.rectangle(image1, top_left, bottom_right, (0, 0, 255), 5)
plt.imshow(cv2.cvtColor(image1, cv2.COLOR_GRAY2RGB))
plt.show()
# Out:
# (-0.542396068572998, 1.0, (498, 160), (300, 280))
